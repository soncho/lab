# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn

# %%
def exp(n):
    return (1 + 1 / n) ** n

# %%
plt.plot([exp(n) for n in np.arange(1, 100)])
plt.show()

# %%
exp(100)
# Out:
# 2.7048138294215285

# %%
import math
def N(x, u, s):
    return (1 / math.sqrt(2 * math.pi * s)) * (math.e ** -((x - u) ** 2 / (2 * s )))

# %%
plt.plot([N(x, 0, 1) for x in np.arange(-5, 5, 0.1)])
plt.show()
